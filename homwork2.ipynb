# %%
#bai1
a =input("nhap chieu dai canh a:")
b =input("nhap chieu rong canh b:")
S= int(a)*int(b)
if a>b:
    print(f" dien tich hinh chu nhat la:{S}")
else :
    print("vui long nhap lai")

# %%
#bai2
r =int(input("nhap ban kinh hinh tron: "))
S = 3.14*r*r
C = 2*3.14*r
print("Dien tich hinh tron la: ", S)
print("Chu vi hinh tron la: ", C)

# %%
#bai3
a =int(input("nhap do dai canh a: "))
b =int(input("nhap do dai canh b: "))
c =int(input("nhap do dai canh c: "))
if a + b > c and a + c > b and b + c > a:
    if a==b and b==c:
        print("3 canh tren tao thanh 1 tam giac deu")
    elif a==b or a==c or b==c:
        print("3 canh tren tao thanh 1 tam giac can")
    elif (a**2 + b**2 == c**2) or (a**2 + c**2 == b**2) or (b**2 + c**2 == a**2):
        print("3 canh tren tao thanh 1 tam giac vuong")
    else:
        print("la tam giac thuong")
else:
    print("khong phai tam giac")

# %%
#bai4
a =int(input("nhap so a: "))
b =int(input("nhap so b: "))
# x =-b/a
if a==0:
    if b==0:
        print("phuong trinh vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
else:
    print("phuong trinh co nghiem x=",-b/a)

# %%
#bai5
a =int(input("nhap so a: "))
b =int(input("nhap so b: "))
c =int(input("nhap so c: "))
if a == 0:
    print("vui long nhap lai a")
else:
    if b**2-4*a*c<0:
        print("phuong trinh vo nghiem")
    elif b**2-4*a*c==0:
        x=-b/(2*a)
        print("phuong trinh co nghiem kep x=",x)
    else:
        x1=(-b+(b**2-4*a*c)**0.5)/(2*a)
        x2=(-b-(b**2-4*a*c)**0.5)/(2*a)
        print("phuong trinh co 2 nghiem phan biet x1=",x1,"va x2=",x2)

# %%
#bai6
a =float(input("nhap so a: "))
b =float(input("nhap so b: "))
c =float(input("nhap so c: "))
d =float(input("nhap so d: "))
x =max(a,b,c,d)
print("so lon nhat la: ",x)

# %%
#bai7
a =float(input("nhap so a: "))
b =float(input("nhap so b: "))
c =float(input("nhap so c: "))
d =float(input("nhap so d: "))
x =min(a,b,c,d)
print("so nho nhat la: ",x)

# %%
#bai8
a =int(input("nhap so a:"))
b =int(input("nhap so b:"))
m =int(input("nhap so m:"))
c =int(input("nhap so c:"))
d =int(input("nhap so d:"))
n =int(input("nhap so n:"))
if a*d-b*c==0:
    print("vui long nhap lai")
else:
    x=(m*d-n*b)/(a*d-b*c)
    y=(a*n-m*c)/(a*d-b*c)
    print(f"nghiem cua he phuong trinh la:x={round(x, 2)},y={round(y, 2)}")

# %%
#bai9
x=int(input("nhap so giay:"))
print("so gio là :",x/3600)
print("so phut la :",x/60)
print("so giay la :",60)

# %%
#bai10
a =int(input("nhap diem a :"))
b =int(input("nhap diem b :"))
r =int(input("nhap diem r :"))
t = (-2*a-2*b)/4-(a**2+b**2-r**2)
if t>0:
    print("la phuong trinh duong tron")
    print("vui long nhap toa do diem A")
    x = int(input("nhap diem x :"))
    y = int(input("nhap diem y :"))
    o = x**2+y**2-2*a*x-2*b*y+a**2+b**2
    if o == r**2 :
        print("diem A thuoc phuong trinh duong tron ")
    else:
        print("diem A khong thuoc phuong trinh duong tron")
else:
    print("vui long nhap lai")

# %%
#bai11
x =float(input("nhap x :"))
y =float(input("nhap y :"))
print("vay x^y la :",x**y)
