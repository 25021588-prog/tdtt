# %%
#w2a1
print("Hello, World!")

# %%
#w2a2
input("nhập tên của bạn: ")
print("Chào mừng bạn đến với khóa học Python!")

# %%
#w2a3
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
x =a+b
y =a-b
z =a*b
t =a/b
r =a//b
i =a%b
print(x,y,z,t,r,i)

# %%
#w2a4
a1, a2, a3, b1, b2, b3, c1, c2, c3 = map(int, input().split())
TB = ((a1 + b1 + c1) + (a2 + b2)*2+a3*3) / 10
x = round(TB, 2)
print("Diem trung binh cua 3 mon la:", x)

# %%
#w2a5
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
x = a**b
print(f"{a} mũ {b} là: {x}")

# %%
#xep loai hoc luc
dtb = float(input("Nhap diem trung binh: "))
if dtb>0 and dtb<10:
    print("diem trung binh hop le")
    if dtb >= 9:
        print("Xep loai: Xuat sac")
    elif dtb >= 8:
        print("Xep loai: Gioi")
    elif dtb >= 7:
        print("Xep loai: Kha")
    elif dtb >= 5:
        print("Xep loai: Trung binh")
    else:
        print("Xep loai: Yeu")

else:
    print("diem trung binh khong hop le")

# %%
#w2a6
x =input("nhap 1 chu thuong :")
if len(x) !=1 or not x.lower :
    print("vui long nhap chu thuong")
else :
    print(f"ma unicode cua '{x}' la :",{ord(x)})
    x=x.upper()
    print(f"Ký tự hoa tương ứng là: {x}")

# %%
#w2a7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(f"ket qua cua A là:{A}")
print(f"ket qua cua B là:{B}")

# %%
#w2a8
x = input("nhap nhiet do C:")
x = float(x)
y = (9/5)*x+32
print("nhiet do F la:",y)

# %%
#w2a9
x =input("nhap so tien usd:")
x =float(x)
t =x+0.3*x+0.1*x
t =round(t,2)
print("so tien la :",t)

# %%
#w2a10
x = input("nhap 3 ten :")
x = x.split()
if len(x) != 3:
    print("Vui long nhap dung 3 ten")
else:
    reversed_x=x[::-1]
    name1, name2, name3 = reversed_x
    print(f"hi {name1} {name2} and {name3}")
